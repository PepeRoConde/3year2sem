# %%
from Algoritmos import MonteCarlo, Sarsa, Q_Aprendizaxe
import numpy as np
import pygame

# %%
mc = MonteCarlo()
mc.mostra_q()

# %%
mc.q = np.load('MonteCarlo__g_0%99_e_0%3_alpha_None.npy')
mc.mostra_q()

# %%
mc.proba()
mc.env.close()
pygame.quit()
# Out:
# Episodio de proba 1/1. Recompensa: -1043.63
#
# Recompensa media -1043.63
